# %%
import google.generativeai as genai

# %%
# genai.configure(api_key='')

# %%
model=genai.GenerativeModel('gemini-2.5-flash')

# %%
print("Gemini AI Chatbot")
print("Type 'exit' to end the chat.")

while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("Goodbye...")
        break
    response = model.generate_content(user_input)
    print("Gemini: " ,response.text)
# Out:
# Gemini AI Chatbot
# Type 'exit' to end the chat.
# Gemini:  The **BMW M340i** is a fantastic car and a standout in the compact luxury sports sedan segment. It sits at the top of the non-M 3 Series range, bridging the gap between the standard 330i and the full-blown M3.
#
# Here's a breakdown of what makes the M340i special:
#
# ## Key Characteristics of the BMW M340i (Current G20 Generation)
#
# 1.  **Engine (The Heart of the Beast):**
#     *   **B58 Engine:** This is arguably the M340i's biggest selling point. It features BMW's superb B58 3.0-liter turbocharged inline-six-cylinder engine.
#     *   **Power:** In the US market, it typically produces **382 horsepower** and **369 lb-ft of torque**. (Other markets may have slightly different figures due to emissions regulations).
#     *   **Performance:** This translates to incredibly rapid acceleration, with 0-60 mph times often quoted in the **low 4-second range** (around 4.1-4.2 seconds for the xDrive model), making it quicker than many V8-powered cars of just a few years ago.
#
# 2.  **Transmission:**
#     *   It comes exclusively with the renowned **ZF 8-speed automatic transmission**. This transmission is lauded for its lightning-fast shifts, smooth operation, and ability to be both a refined cruiser and an aggressive performer when needed.
#
# 3.  **Drivetrain:**
#     *   **xDrive (AWD):** The M340i is primarily sold with BMW's xDrive all-wheel-drive system, especially in regions with varying weather conditions. This provides exceptional traction and stability.
#     *   **RWD (Rare):** A rear-wheel-drive (RWD) version is available in some markets (like the US), offering a purer, more traditional BMW driving experience, but it's less common.
#
# 4.  **Chassis & Handling:**
#     *   **M Sport Suspension:** Comes standard, offering a firmer, sportier ride than the regular 3 Series.
#     *   **Adaptive M Suspension:** An optional upgrade that allows drivers to adjust damper stiffness, providing a more comfortable ride in "Comfort" mode and a sharper, more controlled ride in "Sport" modes.
#     *   **M Sport Brakes:** Larger, more powerful brakes come standard, providing excellent stopping power.
#     *   **M Sport Differential:** Electronically controlled limited-slip differential on the rear axle (standard with xDrive, optional with RWD), enhancing grip and handling during hard cornering.
#     *   **Balance:** Excellent 50/50 weight distribution contributes to its agile and balanced handling.
#
# 5.  **Exterior Design:**
#     *   **Aggressive M Styling:** Features unique M Performance specific styling elements, including more aggressive front and rear bumpers, a distinct kidney grille design, unique wheel options, and trapezoidal exhaust finishers.
#     *   **Shadowline Trim:** Often comes with blacked-out trim instead of chrome.
#
# 6.  **Interior & Technology:**
#     *   **Luxurious and Tech-Forward:** The interior is a blend of premium materials, modern design, and advanced technology.
#     *   **iDrive System:** Features BMW's latest iDrive infotainment system (iDrive 7 or 8/8.5 depending on model year and LCI update) with a large central display and digital instrument cluster. It includes navigation, Apple CarPlay, Android Auto, and voice control.
#     *   **M Sport Seats:** Sport seats with enhanced bolstering are standard or optional, providing better support during spirited driving.
#     *   **Driver Assistance:** Available with a comprehensive suite of driver assistance features, including adaptive cruise control, lane-keeping assist, blind-spot monitoring, and more.
#
# ## Why Choose an M340i?
#
# *   **"M-Lite" Performance:** It delivers a significant punch and a truly engaging driving experience, feeling very close to a full M car in many respects, especially its straight-line speed.
# *   **Daily Drivability:** Unlike the more extreme M3, the M340i retains a high degree of comfort and refinement, making it an excellent daily driver. It's quieter, smoother, and less jarring for everyday commutes.
# *   **Value:** It offers much of the performance thrill of an M car at a considerably lower price point, making it a "sweet spot" in the BMW lineup.
# *   **Understated:** While it looks aggressive, it's not as overtly "shouty" as an M3, appealing to those who prefer performance with a touch more subtlety.
#
# ## Current Generation (G20/G21)
#
# The current generation of the 3 Series (G20 sedan, G21 Touring/wagon) was introduced for the 2019 model year, with the M340i following shortly after. It received a **Life Cycle Impulse (LCI)**, or facelift, for the 2023 model year, which brought updated exterior styling (headlights, grille, bumpers) and a significant interior overhaul, including the curved display with iDrive 8 (or 8.5 in later models).
#
# In summary, the BMW M340i is a phenomenal package, offering a thrilling blend of performance, luxury, and everyday usability. It's often considered one of the best performance sedans on the market today.
# Gemini:  The **Audi A6** is a mid-size luxury sedan (or executive car) produced by the German automaker Audi. It's a key model in Audi's lineup, known for its blend of sophisticated design, advanced technology, premium comfort, and refined performance.
#
# Here's a breakdown of what generally defines the Audi A6:
#
# 1.  **Segment:** It competes in the E-segment, directly against rivals like the Mercedes-Benz E-Class, BMW 5 Series, Volvo S90, and Lexus ES.
#
# 2.  **Design:**
#     *   **Exterior:** Characterized by its elegant, understated, yet modern aesthetic. It features Audi's signature Singleframe grille, sharp lines, and distinctive LED lighting (often with advanced Matrix LED options). It projects a sense of restrained luxury rather than overt flashiness.
#     *   **Interior:** Known for its high-quality materials (leather, wood, aluminum), exceptional craftsmanship, and minimalistic design. The focus is on ergonomics, comfort, and a high-tech ambiance.
#
# 3.  **Technology:** This is a major selling point for the A6.
#     *   **MMI Touch Response:** A dual-screen infotainment system that controls most vehicle functions, providing haptic feedback.
#     *   **Audi Virtual Cockpit:** A customizable digital instrument cluster that can display navigation, media, and vehicle information in stunning clarity.
#     *   **Driver-Assistance Systems:** A comprehensive suite of features including adaptive cruise control, lane-keeping assist, blind-spot monitoring, park assist, and more, often bundled into "Tour" or "City" assist packages.
#     *   **Connectivity:** Features like Apple CarPlay, Android Auto, onboard Wi-Fi, and various Audi Connect services are standard or optional.
#
# 4.  **Performance:**
#     *   **Engines:** Offers a range of powerful and efficient turbocharged gasoline (TFSI) and diesel (TDI) engines, often paired with mild-hybrid (MHEV) technology for improved efficiency and smoother start/stop operation.
#     *   **Transmission:** Typically uses a smooth-shifting S tronic (dual-clutch) or Tiptronic (conventional automatic) transmission.
#     *   **Quattro All-Wheel Drive:** Audi's renowned permanent all-wheel-drive system is standard on many models and provides excellent traction and stability in various conditions.
#     *   **Ride & Handling:** The A6 prioritizes a comfortable and refined ride, making it an excellent long-distance cruiser. While capable in corners, its handling is more geared towards composed elegance than outright sportiness (though the S6 and RS6 variants change this).
#
# 5.  **Variants:**
#     *   **A6 Sedan:** The standard four-door sedan.
#     *   **A6 Avant:** A stylish and practical station wagon version, particularly popular in Europe, offering increased cargo space without sacrificing luxury.
#     *   **A6 allroad quattro:** A ruggedized version of the Avant with increased ground clearance, body cladding, and often adaptive air suspension for light off-road capability.
#     *   **S6:** The performance-oriented variant, featuring a more powerful engine (often a V6 or V8), sport-tuned suspension, upgraded brakes, and subtle aesthetic enhancements.
#     *   **RS6 Avant:** The high-performance flagship model, exclusively available as a wagon in most markets, boasting a twin-turbo V8 engine, aggressive styling, and track-ready performance.
#
# 6.  **Target Audience:** The A6 appeals to professionals, executives, and families who seek a luxurious, comfortable, and technologically advanced vehicle for daily commuting, business travel, and long road trips. They appreciate understated elegance and cutting-edge features.
#
# In essence, the Audi A6 stands as a strong contender in the executive car segment, offering a compelling blend of premium quality, advanced technology, and refined driving dynamics.
# Goodbye...
