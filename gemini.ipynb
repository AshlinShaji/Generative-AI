# %%
import google.generativeai as genai
# Out:
# C:\Users\ashli\AppData\Local\Temp\ipykernel_16456\613638648.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
# genai.configure(api_key='')

# %%
model=genai.GenerativeModel('gemini-2.5-flash')

# %%
response=model.generate_content("Which is the best movie in the world by audience reviews")        #for asking queston=generate_content()
response.text
# Out:
# 'That\'s a great question, but also a tricky one because "best" is subjective, and different platforms measure audience reviews in different ways!\n\nHowever, when people refer to the "best movie by audience reviews," they are most frequently referencing the **IMDb Top 250 list**, which is ranked purely by user ratings from millions of votes.\n\nOn IMDb, the movie that has consistently held the #1 spot for many years is:\n\n*   **The Shawshank Redemption (1994)**\n\nIt currently holds an average rating of **9.2/10** based on over 2.9 million user ratings (as of late 2023/early 2024).\n\n**Why is it often considered *the* answer?**\n\n*   **Massive Sample Size:** Millions of votes provide a very robust and broad consensus.\n*   **Consistency:** It has maintained its top position for a very long time, indicating enduring appeal.\n*   **Direct User Rating:** IMDb\'s ranking is a direct average of user scores.\n\n**Other strong contenders from other platforms or different metrics:**\n\n*   **Rotten Tomatoes Audience Score:** This measures the percentage of users who rated a movie 3.5 stars or higher. Many movies have 95%+ audience scores, including "The Shawshank Redemption" (usually in the high 90s). Other films like "The Godfather," "The Dark Knight," "Pulp Fiction," and even some newer animated films often have incredibly high audience scores there, though it\'s less about a single "best" and more about broad approval.\n*   **Metacritic User Score:** Similar to IMDb, but generally a smaller user base. "The Shawshank Redemption" also scores very highly here.\n\n**In summary:** If you\'re looking for the single most widely recognized answer based on a comprehensive audience rating system, it\'s almost always **The Shawshank Redemption** due to its unparalleled consistency and high rating on IMDb\'s massive user-driven list.'

# %%
from IPython.display import Markdown
import textwrap
def demo(text):
  return Markdown(textwrap.indent(text,'>'))

# %%
demo(response.text)
# Out:
# >That's a great question, but also a tricky one because "best" is subjective, and different platforms measure audience reviews in different ways!
#
# >However, when people refer to the "best movie by audience reviews," they are most frequently referencing the **IMDb Top 250 list**, which is ranked purely by user ratings from millions of votes.
#
# >On IMDb, the movie that has consistently held the #1 spot for many years is:
#
# >*   **The Shawshank Redemption (1994)**
#
# >It currently holds an average rating of **9.2/10** based on over 2.9 million user ratings (as of late 2023/early 2024).
#
# >**Why is it often considered *the* answer?**
#
# >*   **Massive Sample Size:** Millions of votes provide a very robust and broad consensus.
# >*   **Consistency:** It has maintained its top position for a very long time, indicating enduring appeal.
# >*   **Direct User Rating:** IMDb's ranking is a direct average of user scores.
#
# >**Other strong contenders from other platforms or different metrics:**
#
# >*   **Rotten Tomatoes Audience Score:** This measures the percentage of users who rated a movie 3.5 stars or higher. Many movies have 95%+ audience scores, including "The Shawshank Redemption" (usually in the high 90s). Other films like "The Godfather," "The Dark Knight," "Pulp Fiction," and even some newer animated films often have incredibly high audience scores there, though it's less about a single "best" and more about broad approval.
# >*   **Metacritic User Score:** Similar to IMDb, but generally a smaller user base. "The Shawshank Redemption" also scores very highly here.
#
# >**In summary:** If you're looking for the single most widely recognized answer based on a comprehensive audience rating system, it's almost always **The Shawshank Redemption** due to its unparalleled consistency and high rating on IMDb's massive user-driven list.
