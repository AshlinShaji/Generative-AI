# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate

# %%
# Initialize Gemini model
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.4
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
# Prompt template
prompt = PromptTemplate(
    input_variables=["topic"],
    template="""
Explain {topic} in simple terms.
Give one real-world example.
"""
)

# %%
# LCEL chain (NEW STYLE)
chain = prompt | llm

# %%
# Run chain
result = chain.invoke({"topic": "Machine Learning"})

# %%
print("\n--- Gemini Response ---\n")
print(result.content)
# Out:
# --- Gemini Response ---
#
# Okay, let's break down Machine Learning in the simplest way possible.
#
# ### What is Machine Learning in Simple Terms?
#
# Imagine you're teaching a child what a "cat" is.
#
# 1.  **You show them many pictures of cats** (different breeds, colors, sizes) and say, "That's a cat!"
# 2.  **You also show them pictures of dogs, birds, or other animals** and say, "That's *not* a cat."
# 3.  **The child starts to learn the *patterns*** that define a cat: pointy ears, whiskers, a certain type of tail, how they move, etc. They figure out what makes a cat *a cat*, without you explicitly listing every single rule ("if ears are pointy AND it has whiskers AND it has a tail...").
# 4.  **Eventually, you can show them a *brand new animal* they've never seen before**, and they can correctly say, "That's a cat!" or "That's not a cat!"
#
# **Machine Learning is essentially doing the same thing, but with computers.**
#
# Instead of a child, we have a computer program. Instead of pictures, we feed it vast amounts of **data** (numbers, text, images, sounds). The computer program then uses complex methods (like a smart detective) to find hidden **patterns** and relationships within that data.
#
# Once it has "learned" these patterns, it can then make **predictions, decisions, or classifications on new, unseen data** without being explicitly programmed for every single possibility. It learns from experience, just like the child.
#
# ### One Real-World Example: Spam Email Filter
#
# Think about your email inbox. How does it know which emails are important and which ones are junk (spam)?
#
# 1.  **Training Data:** Email providers have collected millions of emails that humans have previously marked as "spam" or "not spam."
# 2.  **Learning Patterns:** A Machine Learning algorithm is fed all this data. It analyzes the content of the emails, looking for patterns:
#     *   Common words used in spam (e.g., "winner," "free," "urgent," "viagra")
#     *   Suspicious sender addresses or unusual formatting
#     *   Links to untrustworthy websites
#     *   The frequency of certain phrases
# 3.  **Making Predictions:** Once the algorithm has "learned" these patterns, when a **new email** arrives in your inbox, it quickly analyzes it. Based on the patterns it learned, it predicts whether the email is likely spam or not, and then automatically moves it to your spam folder or keeps it in your inbox.
#
# The amazing part is that it constantly gets better! As more people mark emails as spam or not spam, the system learns from that new data and refines its understanding of what constitutes spam.
